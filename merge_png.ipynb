# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#***改成你要的名字
img1 = mpimg.imread("***.png")
img2 = mpimg.imread("***.png")
img3 = mpimg.imread("***.png")
img4 = mpimg.imread("***.png")

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 10)) 
axs[0, 0].imshow(img1)
axs[0, 0].set_title('  ')
axs[0, 0].axis('off')

axs[0, 1].imshow(img2)
axs[0, 1].set_title('  ')
axs[0, 1].axis('off')

axs[1, 0].imshow(img3)
axs[1, 0].set_title('  ')
axs[1, 0].axis('off')

axs[1, 1].imshow(img4)
axs[1, 1].set_title('  ')
axs[1, 1].axis('off')
# Out:
# (np.float64(-0.5), np.float64(721.5), np.float64(392.5), np.float64(-0.5))
