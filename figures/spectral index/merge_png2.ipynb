# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
#***改成你要的名字
img1 = mpimg.imread("SPT0027-50_spectral index.png")
img2 = mpimg.imread("SPT2354-58_spectral index.png")
img3 = mpimg.imread("G09v1.124_spectral index.png")
img4 = mpimg.imread("G12v2.30_spectral index.png")

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10)) 
axs[0, 0].imshow(img1)
axs[0, 0].set_title('  ')
axs[0, 0].axis('off')

axs[0, 1].imshow(img2)
axs[0, 1].set_title('  ')
axs[0, 1].axis('off')

axs[1, 0].imshow(img3)
axs[1, 0].set_title('  ')
axs[1, 0].axis('off')

axs[1, 1].imshow(img4)
axs[1, 1].set_title('  ')
axs[1, 1].axis('off')
# Out:
# (np.float64(-0.5), np.float64(589.5), np.float64(389.5), np.float64(-0.5))
