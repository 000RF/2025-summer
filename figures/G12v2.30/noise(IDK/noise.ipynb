# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img1 = mpimg.imread("spw29(L).png")
img2 = mpimg.imread("spw29(R).png")
img3 = mpimg.imread("spw31(L).png")
img4 = mpimg.imread("spw31(R).png")

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 10)) 
axs[0, 0].imshow(img1)
axs[0, 0].set_title('spw29(L)')
axs[0, 0].axis('off')

axs[0, 1].imshow(img2)
axs[0, 1].set_title('spw29(R)')
axs[0, 1].axis('off')

axs[1, 0].imshow(img3)
axs[1, 0].set_title('spw31(L)')
axs[1, 0].axis('off')

axs[1, 1].imshow(img4)
axs[1, 1].set_title('spw31(R)')
axs[1, 1].axis('off')
# Out:
# (np.float64(-0.5), np.float64(708.5), np.float64(392.5), np.float64(-0.5))
