# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#頻率與flux數據
freq = np.array([9.21e10 ,9.41e10 ,1.04e11 ,1.06e11 ])  # Hz
flux = np.array([6.88e-4 ,7.84e-4 ,1.167e-3 ,1.218e-3 ])  # Jy

#log-log
log_freq = np.log10(freq)
log_flux = np.log10(flux)

#線性擬合：y=αx+c
coeffs = np.polyfit(log_freq, log_flux, 1)
alpha = coeffs[0]


plt.figure(figsize=(6,4))
plt.plot(log_freq, log_flux, 'o', label='data points')
plt.plot(log_freq, np.polyval(coeffs, log_freq), '-', label=f'Fit: α = {alpha:.2f}')
plt.xlabel('log(Frequency [Hz])')
plt.ylabel('log(Flux [Jy])')
plt.title('Spectral Index Fit(G12v2.43)')
plt.grid(True, which='both', ls='-', alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()

print(f"Spectral index α ≈ {alpha:.2f}")
# Out:
# Spectral index α ≈ 4.04
